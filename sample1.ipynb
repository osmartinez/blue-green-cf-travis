# %% [markdown]
# <a href="https://colab.research.google.com/github/osmartinez/blue-green-cf-travis/blob/master/sample1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget "https://github.com/osmartinez/cristallisation-nb/blob/master/Captura%20tipos%20de%20moco%20g%20l%20s%20p.jpg"
# Out:
# --2019-05-24 23:06:00--  https://github.com/osmartinez/cristallisation-nb/blob/master/Captura%20tipos%20de%20moco%20g%20l%20s%20p.jpg
# Resolving github.com (github.com)... 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Captura tipos de moco g l s p.jpg’
#
# Captura tipos de mo     [ <=>                ]  62.02K  --.-KB/s    in 0.1s
#
# 2019-05-24 23:06:01 (494 KB/s) - ‘Captura tipos de moco g l s p.jpg’ saved [63510]

# %%
# !mv Captura\ tipos\ de\ moco\ g\ l\ s\ p.jpg tipos_moco.jpg

# %%
# !ls
# Out:
# sample_data  tipos_moco.jpg

# %%
# Out:
# None
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-07aeac8cf6e1> in <module>()
#       5 img = cv2.imread("tipos_moco.jpg")
#       6 print(img)
# ----> 7 img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       8 plt.imshow(img_cvt)
#       9 plt.show()
#
# error: OpenCV(3.4.3) /io/opencv/modules/imgproc/src/color.cpp:181: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f6cb7cec-4deb-495e-bcc0-68773ea288c2" name="files[]" multiple disabled />
#      <output id="result-f6cb7cec-4deb-495e-bcc0-68773ea288c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Captura tipos de moco g l s p.jpg to Captura tipos de moco g l s p.jpg
# Saving Captura zonas de arborizacion como se va ramificando.jpg to Captura zonas de arborizacion como se va ramificando.jpg
# Saving zona de arboriazacion 3.JPG to zona de arboriazacion 3.JPG
# Saving zona de arborizacion.JPG to zona de arborizacion.JPG
# Saving zonas de arborizacion 2.JPG to zonas de arborizacion 2.JPG
# ...

# %%
# !ls
# Out:
# 'Captura tipos de moco g l s p.jpg'
# 'Captura zonas de arborizacion como se va ramificando.jpg'
#  sample_data
#  tipos_moco.jpg
# 'zona de arboriazacion 3.JPG'
# 'zona de arborizacion.JPG'
# 'zonas de arborizacion 2.JPG'

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread("zona de arboriazacion 3.JPG")
gray=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(gray)
plt.show()

# %%
median =  cv2.medianBlur(gray,5)
median =  cv2.medianBlur(median,5)
median =  cv2.medianBlur(median,5)

kernel = np.ones((1,1),np.uint8)

low_threshold = 150
high_threshold = 200
dilation = cv2.erode(median,kernel,iterations = 1)



_,edges =cv2.threshold(dilation,127,255,cv2.THRESH_BINARY)


plt.imshow(edges)
plt.show()


edges = cv2.Canny(edges, 100, 200)
minLineLength = 10 # Changing this to 100 does nothing.
maxLineGap = 1
threshold = 100
lines = cv2.HoughLinesP(edges,1,np.pi/180,threshold,minLineLength,maxLineGap)
for l in lines:
    for x1,y1,x2,y2 in l:
        cv2.line(median,(x1,y1),(x2,y2),(0,0,255), 2)
plt.imshow(median)
plt.show()

dst = cv2.cornerHarris(dst,10,20,1)
plt.imshow(dst)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-94-b853860acb79> in <module>()
#      29 plt.show()
#      30
# ---> 31 dst = cv2.cornerHarris(dst,10,20,1)
#      32 plt.imshow(dst)
#      33 plt.show()
#
# error: OpenCV(3.4.3) /io/opencv/modules/imgproc/src/deriv.cpp:104: error: (-211:One of arguments' values is out of range) The kernel size must be odd and not larger than 31 in function 'getSobelKernels'
